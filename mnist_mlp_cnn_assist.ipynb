# %% [markdown]
# <a href="https://colab.research.google.com/github/skimaza/assist/blob/main/mnist_mlp_cnn_assist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI 전략경영MBA 경영자를 위한 딥러닝 원리의 이해
# # CNN을 이용한 MNIST 필기체 숫자 인식
# ## MNIST dataset : http://yann.lecun.com/exdb/mnist/

# %% [markdown]
# # 라이브러리 import

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# 학습 실행 시간을 표시하기 위한 함수

# %%
import time

def timer(start, end):
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    return "{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds)

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # PyTorch에서 제공하는 공개 데이터셋 라이브러리 사용
# transform parameter는 데이터셋에 자동으로 적용할 데이터 변환 기능. 여기서는 데이터값을 파이토치 Tensor로 바꾸는 기능만 사용

# %%
transform = transforms.ToTensor()

# %%
# choose the training and testing datasets
train_data = datasets.MNIST(root = 'data', train = True, download = True, transform = transform)
test_data = datasets.MNIST(root = 'data', train = False, download = True, transform = transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
#dataset1 = datasets.MNIST('../data', train=True, download=True, transform=transform)

# %%
#dataset2 = datasets.MNIST('../data', train=False, transform=transform)

# %% [markdown]
# # 다운로드된 데이터 살펴보기

# %%
type(train_data), type(test_data)
# Out:
# (torchvision.datasets.mnist.MNIST, torchvision.datasets.mnist.MNIST)

# %%
print(train_data)
print(test_data)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %% [markdown]
# # 다운로드된 디렉토리 확인

# %%
# !ls data/MNIST/raw
# Out:
# t10k-images-idx3-ubyte	   train-images-idx3-ubyte
# t10k-images-idx3-ubyte.gz  train-images-idx3-ubyte.gz
# t10k-labels-idx1-ubyte	   train-labels-idx1-ubyte
# t10k-labels-idx1-ubyte.gz  train-labels-idx1-ubyte.gz

# %% [markdown]
# ### (Tensor, label) format

# %% [markdown]
# # 전체 데이터 수

# %%
len(train_data), type(train_data[0])
# Out:
# (60000, tuple)

# %% [markdown]
# # 첫번째 데이터의 형태

# %%
len(train_data[0])
# Out:
# 2

# %%
type(train_data[0])
# Out:
# tuple

# %%
len(train_data[0])
# Out:
# 2

# %%
type(train_data[0][0])
# Out:
# torch.Tensor

# %%
train_data[0][0].shape
# Out:
# torch.Size([1, 28, 28])

# %%
train_data[0][0].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# 1개의 28x28 디멘션을 가지는 데이터

# %%
train_data[0][1] # label
# Out:
# 5

# %% [markdown]
# train_data[0][0]에 대한 label. 즉 이미지가 표현하는 십진수

# %% [markdown]
# ## 값의 범위 확인

# %%
for i in range(5):
    print('Max value:', train_data[i][0].max())
    print('Min Value:', train_data[i][0].min())
    print('Label', train_data[i][1])
# Out:
# Max value: tensor(1.)
# Min Value: tensor(0.)
# Label 5
# Max value: tensor(1.)
# Min Value: tensor(0.)
# Label 0
# Max value: tensor(1.)
# Min Value: tensor(0.)
# Label 4
# Max value: tensor(1.)
# Min Value: tensor(0.)
# Label 1
# Max value: tensor(1.)
# Min Value: tensor(0.)
# Label 9

# %% [markdown]
# 데이터셋의 처음 5개 데이터는 0과 1사이의 픽셀값을 갖는 흑백이미지이고 레이블은 각각 5, 0, 4, 1, 9이다.

# %% [markdown]
# # 첫번째 데이터의 일부분만 확인

# %%
train_data[0][0][:15, :15]
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0706, 0.0706, 0.0706,
#           0.4941, 0.5333, 0.6863, 0.1020, 0.6510, 1.0000, 0.9686, 0.4980,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1176, 0.1412, 0.3686, 0.6039, 0.6667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.8824, 0.6745, 0.9922, 0.9490, 0.7647, 0.2510,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922,
#           0.9333, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9843, 0.3647, 0.3216, 0.3216, 0.2196, 0.1529, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765, 0.7137,
#           0.9686, 0.9451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3137, 0.6118, 0.4196, 0.9922, 0.9922, 0.8039, 0.0431, 0.0000,
#           0.1686, 0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0549, 0.0039, 0.6039, 0.9922, 0.3529, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.7451, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0431, 0.7451, 0.9922, 0.2745, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1373, 0.9451, 0.8824, 0.6275,
#           0.4235, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3176, 0.9412, 0.9922,
#           0.9922, 0.4667, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])

# %% [markdown]
# train_data 값의 형태 재확인

# %%
type(train_data[0][0]), train_data[0][0].shape, type(train_data[0][1]), train_data[0][1]
# Out:
# (torch.Tensor, torch.Size([1, 28, 28]), int, 5)

# %% [markdown]
# ### 이미지를 직접 보자

# %% [markdown]
# 이미지를 디스플레이하기 위해 텐서를 numpy 배열로 변환

# %%
img0 = train_data[0][0].numpy()

# %% [markdown]
# matplotlib 기능을 이용하여 디스플레이

# %%
plt.imshow(np.squeeze(img0), 'gray')

# %%
# # convert data to torch.FloatTensor
# transform = transforms.ToTensor()
# # choose the training and testing datasets
# train_data = datasets.MNIST(root = 'data', train = True, download = True, transform = transform)
# test_data = datasets.MNIST(root = 'data', train = False, download = True, transform = transform)

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_index, valid_index = indices[split:], indices[:split]
# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_index)
valid_sampler = SubsetRandomSampler(valid_index)

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, 
                                           sampler = train_sampler, num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size,
                                          sampler = valid_sampler, num_workers = num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size, num_workers = num_workers)

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(labels[idx].item()))

# %%
img = np.squeeze(images[1])
fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# # 베이스라인 MLP 모델 (지난 시간 예제)

# %% [markdown]
# # fully connected layer 2개, 마지막 fully connected output layer가 1개인 Multilayer Perceptron 네트워크 정의
# ### PyTorch에서는 class method인 forward에서 forward propagation을 정의하면 backward propagation 부분은 자동으로 구성해 줌 (autograd 기능)

# %%
# define NN architecture
class MLP(nn.Module):
    def __init__(self):
        super(MLP,self).__init__()
        # number of hidden nodes in each layer (512)
        hidden_1 = 512
        hidden_2 = 512
        # linear layer (784 -> hidden_1)
        self.fc1 = nn.Linear(28*28, 512)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(512,512)
        # linear layer (n_hidden -> 10)
        self.fc3 = nn.Linear(512,10)
        # dropout layer (p=0.2)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)
        
    def forward(self,x):
        # flatten image input. 20개의 28*28 크기의 3차원 입력데이터([20,28,28])인 x를 28*28(=784) 크기의 2차원 데이터로 변환([20,784]).
        # 여기서 정의한 MLP 네트워크에서는 2차원 정보를 이용하지 않음
        x = x.view(-1,28*28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
         # add hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x

# %%
# initialize the NN
model_mlp = MLP()
print(model_mlp)
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# model은 784 -> 512 -> 512 -> 10 의 구조를 가진 MLP

# %% [markdown]
# # Loss (Error)는 분류 문제에 사용하는 CrossEntropyLoss를 사용
# # Gradient descent 알고리즘은 SGD(Stochastic Gradient Descent)를 사용
# # Learning rate는 0.01

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()
# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model_mlp.parameters(),lr = 0.01)

# %% [markdown]
# # 학습 실행
# ### n_epochs를 50으로 설정함
# ### 학습 1번 완료 후 train_data의 loss와 valid_data의 loss와 비교
# ### valid loss가 줄어들었으면 모델을 저장

# %%
# number of epochs to train the model
n_epochs = 50
# initialize tracker for minimum validation loss
valid_loss_min = np.Inf  # set initial "min" to infinity
for epoch in range(n_epochs):
    # monitor losses
    train_loss = 0
    valid_loss = 0
    
    ###################
    # train the model #
    ###################
    model_mlp.train() # prep model for training
    for data,label in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_mlp(data)
        # calculate the loss
        loss = criterion(output,label)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item() * data.size(0)
        
     ######################    
    # validate the model #
    ######################
    model_mlp.eval()  # prep model for evaluation
    for data,label in valid_loader:
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_mlp(data)
        # calculate the loss
        loss = criterion(output,label)
        # update running validation loss 
        valid_loss += loss.item() * data.size(0) # bug
    
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model_mlp.state_dict(), 'model_mlp.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.955404 	Validation Loss: 0.375328
# Validation loss decreased (inf --> 0.375328).  Saving model ...
# Epoch: 2 	Training Loss: 0.356678 	Validation Loss: 0.284242
# Validation loss decreased (0.375328 --> 0.284242).  Saving model ...
# Epoch: 3 	Training Loss: 0.281106 	Validation Loss: 0.235870
# Validation loss decreased (0.284242 --> 0.235870).  Saving model ...
# Epoch: 4 	Training Loss: 0.233004 	Validation Loss: 0.199926
# Validation loss decreased (0.235870 --> 0.199926).  Saving model ...
# Epoch: 5 	Training Loss: 0.197779 	Validation Loss: 0.173278
# Validation loss decreased (0.199926 --> 0.173278).  Saving model ...
# Epoch: 6 	Training Loss: 0.173590 	Validation Loss: 0.153827
# Validation loss decreased (0.173278 --> 0.153827).  Saving model ...
# Epoch: 7 	Training Loss: 0.153152 	Validation Loss: 0.139395
# Validation loss decreased (0.153827 --> 0.139395).  Saving model ...
# Epoch: 8 	Training Loss: 0.135561 	Validation Loss: 0.130953
# Validation loss decreased (0.139395 --> 0.130953).  Saving model ...
# Epoch: 9 	Training Loss: 0.121916 	Validation Loss: 0.118997
# Validation loss decreased (0.130953 --> 0.118997).  Saving model ...
# Epoch: 10 	Training Loss: 0.111774 	Validation Loss: 0.114441
# Validation loss decreased (0.118997 --> 0.114441).  Saving model ...
# Epoch: 11 	Training Loss: 0.102308 	Validation Loss: 0.106050
# Validation loss decreased (0.114441 --> 0.106050).  Saving model ...
# Epoch: 12 	Training Loss: 0.093633 	Validation Loss: 0.100196
# Validation loss decreased (0.106050 --> 0.100196).  Saving model ...
# Epoch: 13 	Training Loss: 0.087952 	Validation Loss: 0.094392
# Validation loss decreased (0.100196 --> 0.094392).  Saving model ...
# Epoch: 14 	Training Loss: 0.080428 	Validation Loss: 0.091558
# Validation loss decreased (0.094392 --> 0.091558).  Saving model ...
# Epoch: 15 	Training Loss: 0.075866 	Validation Loss: 0.089233
# Validation loss decreased (0.091558 --> 0.089233).  Saving model ...
# Epoch: 16 	Training Loss: 0.070455 	Validation Loss: 0.085998
# Validation loss decreased (0.089233 --> 0.085998).  Saving model ...
# Epoch: 17 	Training Loss: 0.065568 	Validation Loss: 0.081805
# Validation loss decreased (0.085998 --> 0.081805).  Saving model ...
# Epoch: 18 	Training Loss: 0.061775 	Validation Loss: 0.080105
# Validation loss decreased (0.081805 --> 0.080105).  Saving model ...
# Epoch: 19 	Training Loss: 0.057047 	Validation Loss: 0.078461
# Validation loss decreased (0.080105 --> 0.078461).  Saving model ...
# Epoch: 20 	Training Loss: 0.053049 	Validation Loss: 0.077004
# Validation loss decreased (0.078461 --> 0.077004).  Saving model ...
# Epoch: 21 	Training Loss: 0.050721 	Validation Loss: 0.074382
# Validation loss decreased (0.077004 --> 0.074382).  Saving model ...
# Epoch: 22 	Training Loss: 0.048657 	Validation Loss: 0.072727
# Validation loss decreased (0.074382 --> 0.072727).  Saving model ...
# Epoch: 23 	Training Loss: 0.044620 	Validation Loss: 0.073470
# Epoch: 24 	Training Loss: 0.043990 	Validation Loss: 0.070966
# Validation loss decreased (0.072727 --> 0.070966).  Saving model ...
# Epoch: 25 	Training Loss: 0.040458 	Validation Loss: 0.069584
# Validation loss decreased (0.070966 --> 0.069584).  Saving model ...
# Epoch: 26 	Training Loss: 0.039219 	Validation Loss: 0.069184
# Validation loss decreased (0.069584 --> 0.069184).  Saving model ...
# Epoch: 27 	Training Loss: 0.036863 	Validation Loss: 0.068488
# Validation loss decreased (0.069184 --> 0.068488).  Saving model ...
# Epoch: 28 	Training Loss: 0.035154 	Validation Loss: 0.068395
# Validation loss decreased (0.068488 --> 0.068395).  Saving model ...
# Epoch: 29 	Training Loss: 0.033426 	Validation Loss: 0.067956
# Validation loss decreased (0.068395 --> 0.067956).  Saving model ...
# Epoch: 30 	Training Loss: 0.030908 	Validation Loss: 0.067046
# Validation loss decreased (0.067956 --> 0.067046).  Saving model ...
# Epoch: 31 	Training Loss: 0.029643 	Validation Loss: 0.068329
# Epoch: 32 	Training Loss: 0.028173 	Validation Loss: 0.066584
# Validation loss decreased (0.067046 --> 0.066584).  Saving model ...
# Epoch: 33 	Training Loss: 0.027791 	Validation Loss: 0.065052
# Validation loss decreased (0.066584 --> 0.065052).  Saving model ...
# Epoch: 34 	Training Loss: 0.026518 	Validation Loss: 0.065385
# Epoch: 35 	Training Loss: 0.024590 	Validation Loss: 0.065669
# Epoch: 36 	Training Loss: 0.023697 	Validation Loss: 0.064811
# Validation loss decreased (0.065052 --> 0.064811).  Saving model ...
# Epoch: 37 	Training Loss: 0.022673 	Validation Loss: 0.065340
# Epoch: 38 	Training Loss: 0.021896 	Validation Loss: 0.064947
# Epoch: 39 	Training Loss: 0.020926 	Validation Loss: 0.064985
# Epoch: 40 	Training Loss: 0.020335 	Validation Loss: 0.064919
# Epoch: 41 	Training Loss: 0.018370 	Validation Loss: 0.064938
# Epoch: 42 	Training Loss: 0.018651 	Validation Loss: 0.064540
# Validation loss decreased (0.064811 --> 0.064540).  Saving model ...
# Epoch: 43 	Training Loss: 0.017163 	Validation Loss: 0.063178
# Validation loss decreased (0.064540 --> 0.063178).  Saving model ...
# Epoch: 44 	Training Loss: 0.016370 	Validation Loss: 0.064770
# Epoch: 45 	Training Loss: 0.017295 	Validation Loss: 0.065604
# Epoch: 46 	Training Loss: 0.016032 	Validation Loss: 0.064742
# Epoch: 47 	Training Loss: 0.015257 	Validation Loss: 0.064045
# Epoch: 48 	Training Loss: 0.015048 	Validation Loss: 0.064778
# Epoch: 49 	Training Loss: 0.013522 	Validation Loss: 0.064747
# Epoch: 50 	Training Loss: 0.013110 	Validation Loss: 0.066790

# %% [markdown]
# # 저장된 모델 로드

# %%
model_mlp.load_state_dict(torch.load('model_mlp.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # test 데이터셋에 대해 인식률 계산

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
model_mlp.eval() # prep model for evaluation
for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model_mlp(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.059019
#
# Test Accuracy of     0: 99% (972/980)
# Test Accuracy of     1: 99% (1125/1135)
# Test Accuracy of     2: 97% (1006/1032)
# Test Accuracy of     3: 98% (995/1010)
# Test Accuracy of     4: 98% (964/982)
# Test Accuracy of     5: 97% (871/892)
# Test Accuracy of     6: 98% (943/958)
# Test Accuracy of     7: 97% (1005/1028)
# Test Accuracy of     8: 97% (947/974)
# Test Accuracy of     9: 97% (987/1009)
#
# Test Accuracy (Overall): 98% (9815/10000)

# %% [markdown]
# # 약 98% 정확도 달성
# # 실제 이미지를 보고 성능 확인
# 아래 예제에서는 하나의 미니배치(20개) 이미지를 확인함

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
# get sample outputs
output = model_mlp(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()
# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
max_images = batch_size
for idx in np.arange(max_images):
    ax = fig.add_subplot(2, max_images/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))

# %% [markdown]
# 오류인 경우를 보기위해 틀릴 때까지 반복

# %%
fail = False
for images, labels in dataiter:
    # get sample outputs
    output = model_mlp(images)
    # convert output probabilities to predicted class
    _, preds = torch.max(output, 1)
    # prep images for display
    images = images.numpy()
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(25, 4))
    for idx in np.arange(20):
        ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(images[idx]), cmap='gray')
        ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                    color=("green" if preds[idx]==labels[idx] else "red"))
        if preds[idx] != labels[idx]:
            fail = True
    plt.show()
    if fail:
        break

# %% [markdown]
# **<font color="red" size="4">여기까지 지난 시간 예제와 동일</font>**

# %% [markdown]
# # 기본 구조 CNN (Vanailla CNN)

# %% [markdown]
# * 두 Conv 레이어 정의
#     * 1 to 32 : 입력이 1 채널, 32개의 3x3 커널 학습, 이동(stride)은 한 칸씩
#     * 32 to 64 : 입력이 32 채널, 64개의 3x3 커널 학습, 이동(stride)은 한 칸씩
#
# * 레이어 별 dropout 정의
#     * 25%를 dropout, 50%를 dropout

# %% [markdown]
# no dropout, padding 1, 2 layer

# %% [markdown]
# nn.Conv2d(in_channels, out_channels, kernel_size)

# %%
class MnistVanillaCNN(nn.Module):
    def __init__(self):
        super(MnistVanillaCNN, self).__init__() # 여기도 함께 바꿔줘야 함
        self.conv1 = nn.Conv2d(1, 32, 3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=1, padding=1)
        #self.dropout1 = nn.Dropout(0.25)
        #self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(7*7*64, 128)
        self.fc2 = nn.Linear(128, 10)

    # weight가 없는 activation function은 __init__에서 변수로 저장하지 않아도 된다
    def forward(self, x):
        x = self.conv1(x) # Conv -> ReLU
        x = F.relu(x)     # nn.ReLU와 동일한 계산을 수행. F.relu()는 계산, nn.ReLU()는 계산을 수행하는 모듈을 리턴함.
        x = F.max_pool2d(x, 2)  # max pooling 도 weight가 없음.
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        #x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        #x = self.dropout2(x)
        x = self.fc2(x)
        #output = F.log_softmax(x, dim=1)
        return x # output

# %%
# initialize the NN
model_v = MnistVanillaCNN()
print(model_v)
# Out:
# MnistVanillaCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=3136, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ## Vanilla CNN train

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()
# specify optimizer (stochastic gradient descent) and learning rate = 0.01
#optimizer = torch.optim.SGD(model.parameters(),lr = 0.01)
optimizer_v = torch.optim.SGD(model_v.parameters(),lr = 0.01)

# %%
# number of epochs to train the model
n_epochs = 25
# initialize tracker for minimum validation loss
valid_loss_min = np.Inf  # set initial "min" to infinity
start = time.time()
for epoch in range(n_epochs):
    # monitor losses
    train_loss = 0
    valid_loss = 0
    
     
    ###################
    # train the model #
    ###################
    model_v.train() # prep model for training
    for data,label in train_loader:
        # clear the gradients of all optimized variables
        optimizer_v.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_v(data)
        # calculate the loss
        loss = criterion(output, label)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer_v.step()
        # update running training loss
        train_loss += loss.item() * data.size(0)
        
        
     ######################    
    # validate the model #
    ######################
    model_v.eval()  # prep model for evaluation
    for data, label in valid_loader:
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_v(data)
        # calculate the loss
        loss = criterion(output, label)
        # update running validation loss 
        valid_loss += loss.item() * data.size(0) # bug
    
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)
    
    end = time.time()
    print('Vanilla: Epoch:{} Elapsed time:{} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        timer(start, end),
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model_v.state_dict(), 'model_v.pt')
        valid_loss_min = valid_loss
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Vanilla: Epoch:1 Elapsed time:00:00:54.76 	Training Loss: 0.607373 	Validation Loss: 0.188475
# Validation loss decreased (inf --> 0.188475).  Saving model ...
# Vanilla: Epoch:2 Elapsed time:00:01:49.61 	Training Loss: 0.145478 	Validation Loss: 0.116873
# Validation loss decreased (0.188475 --> 0.116873).  Saving model ...
# Vanilla: Epoch:3 Elapsed time:00:02:46.21 	Training Loss: 0.095320 	Validation Loss: 0.088326
# Validation loss decreased (0.116873 --> 0.088326).  Saving model ...
# Vanilla: Epoch:4 Elapsed time:00:03:42.93 	Training Loss: 0.073115 	Validation Loss: 0.080682
# Validation loss decreased (0.088326 --> 0.080682).  Saving model ...
# Vanilla: Epoch:5 Elapsed time:00:04:38.72 	Training Loss: 0.061312 	Validation Loss: 0.057374
# Validation loss decreased (0.080682 --> 0.057374).  Saving model ...
# Vanilla: Epoch:6 Elapsed time:00:05:34.61 	Training Loss: 0.052162 	Validation Loss: 0.051467
# Validation loss decreased (0.057374 --> 0.051467).  Saving model ...
# Vanilla: Epoch:7 Elapsed time:00:06:30.42 	Training Loss: 0.046255 	Validation Loss: 0.062389
# Vanilla: Epoch:8 Elapsed time:00:07:25.64 	Training Loss: 0.041370 	Validation Loss: 0.048865
# Validation loss decreased (0.051467 --> 0.048865).  Saving model ...
# Vanilla: Epoch:9 Elapsed time:00:08:21.30 	Training Loss: 0.036531 	Validation Loss: 0.052006
# Vanilla: Epoch:10 Elapsed time:00:09:17.21 	Training Loss: 0.033536 	Validation Loss: 0.044065
# Validation loss decreased (0.048865 --> 0.044065).  Saving model ...
# Vanilla: Epoch:11 Elapsed time:00:10:12.47 	Training Loss: 0.029786 	Validation Loss: 0.043760
# Validation loss decreased (0.044065 --> 0.043760).  Saving model ...
# Vanilla: Epoch:12 Elapsed time:00:11:08.06 	Training Loss: 0.027663 	Validation Loss: 0.040542
# Validation loss decreased (0.043760 --> 0.040542).  Saving model ...
# Vanilla: Epoch:13 Elapsed time:00:12:03.83 	Training Loss: 0.024959 	Validation Loss: 0.042763
# Vanilla: Epoch:14 Elapsed time:00:12:59.41 	Training Loss: 0.022216 	Validation Loss: 0.040174
# Validation loss decreased (0.040542 --> 0.040174).  Saving model ...
# Vanilla: Epoch:15 Elapsed time:00:13:54.48 	Training Loss: 0.020384 	Validation Loss: 0.037302
# Validation loss decreased (0.040174 --> 0.037302).  Saving model ...
# Vanilla: Epoch:16 Elapsed time:00:14:50.36 	Training Loss: 0.018982 	Validation Loss: 0.041881
# Vanilla: Epoch:17 Elapsed time:00:15:46.14 	Training Loss: 0.016884 	Validation Loss: 0.042969
# Vanilla: Epoch:18 Elapsed time:00:16:41.55 	Training Loss: 0.015004 	Validation Loss: 0.038997
# Vanilla: Epoch:19 Elapsed time:00:17:36.66 	Training Loss: 0.013852 	Validation Loss: 0.041411
# Vanilla: Epoch:20 Elapsed time:00:18:31.99 	Training Loss: 0.012590 	Validation Loss: 0.040862
# Vanilla: Epoch:21 Elapsed time:00:19:27.28 	Training Loss: 0.011786 	Validation Loss: 0.037582
# Vanilla: Epoch:22 Elapsed time:00:20:21.95 	Training Loss: 0.010212 	Validation Loss: 0.047594
# Vanilla: Epoch:23 Elapsed time:00:21:17.02 	Training Loss: 0.009752 	Validation Loss: 0.038554
# Vanilla: Epoch:24 Elapsed time:00:22:11.80 	Training Loss: 0.008004 	Validation Loss: 0.040103
# Vanilla: Epoch:25 Elapsed time:00:23:07.15 	Training Loss: 0.007508 	Validation Loss: 0.039795

# %% [markdown]
# 저장된 모델 로드

# %%
model_v.load_state_dict(torch.load('model_v.pt'))
# Out:
# <All keys matched successfully>

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10)) # 숫자별 맞힌 개수
class_total = list(0. for i in range(10)) # 숫자별 총 테스트 개수
model_v.eval() # prep model for evaluation
for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model_v(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.030660
#
# Test Accuracy of     0: 99% (975/980)
# Test Accuracy of     1: 99% (1131/1135)
# Test Accuracy of     2: 99% (1022/1032)
# Test Accuracy of     3: 99% (1004/1010)
# Test Accuracy of     4: 98% (967/982)
# Test Accuracy of     5: 98% (878/892)
# Test Accuracy of     6: 98% (942/958)
# Test Accuracy of     7: 98% (1016/1028)
# Test Accuracy of     8: 98% (961/974)
# Test Accuracy of     9: 98% (992/1009)
#
# Test Accuracy (Overall): 98% (9888/10000)

# %%
# obtain one batch of test images
dataiter = iter(test_loader)

# %% [markdown]
# 처음 20개 샘플 테스트

# %%
images, labels = dataiter.next()
# get sample outputs
output = model_v(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()
# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))

# %% [markdown]
# 오류인 경우를 보기위해 틀릴 때까지 반복

# %%
fail = False
for images, labels in dataiter:
    # get sample outputs
    output = model_v(images)
    # convert output probabilities to predicted class
    _, preds = torch.max(output, 1)
    # prep images for display
    images = images.numpy()
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(25, 4))
    for idx in np.arange(20):
        ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(images[idx]), cmap='gray')
        ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                    color=("green" if preds[idx]==labels[idx] else "red"))
        if preds[idx] != labels[idx]:
            fail = True
    plt.show()
    if fail:
        break

# %% [markdown]
# ## dropout regularization 적용

# %%
class MnistCNN(nn.Module):
    def __init__(self):
        super(MnistCNN, self).__init__() # 여기도 함께 바꿔줘야 함
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    # weight가 없는 activation function은 __init__에서 변수로 저장하지 않아도 된다
    def forward(self, x):
        x = self.conv1(x) # Conv -> ReLU
        x = F.relu(x)     # nn.ReLU와 동일한 계산을 수행. F.relu()는 계산, nn.ReLU()는 계산을 수행하는 모듈을 리턴함.
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2) # max pooling 도 weight가 없음.
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        #output = F.log_softmax(x, dim=1)
        return x # output
        
# initialize the NN
model = MnistCNN()
print(model)
# Out:
# MnistCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()
# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model.parameters(),lr = 0.01)

# %%
# number of epochs to train the model
n_epochs = 40
# initialize tracker for minimum validation loss
valid_loss_min = np.Inf  # set initial "min" to infinity
start = time.time()
for epoch in range(n_epochs):
    # monitor losses
    train_loss = 0
    valid_loss = 0
    
     
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data,label in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output,label)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item() * data.size(0)
        
        
     ######################    
    # validate the model #
    ######################
    model.eval()  # prep model for evaluation
    for data,label in valid_loader:
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output,label)
        # update running validation loss 
        valid_loss += loss.item() * data.size(0) # bug
    
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)
    
    end = time.time()
    print('Vanilla: Epoch:{} Elapsed time:{} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        timer(start, end),
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Vanilla: Epoch:1 Elapsed time:00:01:45.81 	Training Loss: 0.566745 	Validation Loss: 0.222195
# Validation loss decreased (inf --> 0.222195).  Saving model ...
# Vanilla: Epoch:2 Elapsed time:00:03:31.11 	Training Loss: 0.286831 	Validation Loss: 0.157559
# Validation loss decreased (0.222195 --> 0.157559).  Saving model ...
# Vanilla: Epoch:3 Elapsed time:00:05:17.67 	Training Loss: 0.220816 	Validation Loss: 0.123938
# Validation loss decreased (0.157559 --> 0.123938).  Saving model ...
# Vanilla: Epoch:4 Elapsed time:00:07:05.48 	Training Loss: 0.168262 	Validation Loss: 0.094218
# Validation loss decreased (0.123938 --> 0.094218).  Saving model ...
# Vanilla: Epoch:5 Elapsed time:00:08:51.96 	Training Loss: 0.134136 	Validation Loss: 0.075156
# Validation loss decreased (0.094218 --> 0.075156).  Saving model ...
# Vanilla: Epoch:6 Elapsed time:00:10:37.78 	Training Loss: 0.114020 	Validation Loss: 0.066180
# Validation loss decreased (0.075156 --> 0.066180).  Saving model ...
# Vanilla: Epoch:7 Elapsed time:00:12:21.93 	Training Loss: 0.096222 	Validation Loss: 0.060874
# Validation loss decreased (0.066180 --> 0.060874).  Saving model ...
# Vanilla: Epoch:8 Elapsed time:00:14:05.58 	Training Loss: 0.087381 	Validation Loss: 0.055671
# Validation loss decreased (0.060874 --> 0.055671).  Saving model ...
# Vanilla: Epoch:9 Elapsed time:00:15:51.91 	Training Loss: 0.076367 	Validation Loss: 0.049675
# Validation loss decreased (0.055671 --> 0.049675).  Saving model ...
# Vanilla: Epoch:10 Elapsed time:00:17:36.72 	Training Loss: 0.070868 	Validation Loss: 0.047671
# Validation loss decreased (0.049675 --> 0.047671).  Saving model ...
# Vanilla: Epoch:11 Elapsed time:00:19:20.44 	Training Loss: 0.064974 	Validation Loss: 0.046204
# Validation loss decreased (0.047671 --> 0.046204).  Saving model ...
# Vanilla: Epoch:12 Elapsed time:00:21:04.66 	Training Loss: 0.059063 	Validation Loss: 0.043855
# Validation loss decreased (0.046204 --> 0.043855).  Saving model ...
# Vanilla: Epoch:13 Elapsed time:00:22:47.74 	Training Loss: 0.056804 	Validation Loss: 0.040792
# Validation loss decreased (0.043855 --> 0.040792).  Saving model ...
# Vanilla: Epoch:14 Elapsed time:00:24:36.66 	Training Loss: 0.052192 	Validation Loss: 0.044302
# Vanilla: Epoch:15 Elapsed time:00:26:23.51 	Training Loss: 0.050056 	Validation Loss: 0.039496
# Validation loss decreased (0.040792 --> 0.039496).  Saving model ...
# Vanilla: Epoch:16 Elapsed time:00:28:08.20 	Training Loss: 0.047745 	Validation Loss: 0.040461
# Vanilla: Epoch:17 Elapsed time:00:29:52.31 	Training Loss: 0.043141 	Validation Loss: 0.041330
# Vanilla: Epoch:18 Elapsed time:00:31:37.61 	Training Loss: 0.041895 	Validation Loss: 0.037473
# Validation loss decreased (0.039496 --> 0.037473).  Saving model ...
# Vanilla: Epoch:19 Elapsed time:00:33:22.20 	Training Loss: 0.040818 	Validation Loss: 0.039957
# Vanilla: Epoch:20 Elapsed time:00:35:05.68 	Training Loss: 0.037938 	Validation Loss: 0.039086
# Vanilla: Epoch:21 Elapsed time:00:36:47.79 	Training Loss: 0.038583 	Validation Loss: 0.036266
# Validation loss decreased (0.037473 --> 0.036266).  Saving model ...
# Vanilla: Epoch:22 Elapsed time:00:38:35.21 	Training Loss: 0.033636 	Validation Loss: 0.037356
# Vanilla: Epoch:23 Elapsed time:00:40:17.34 	Training Loss: 0.032409 	Validation Loss: 0.035880
# Validation loss decreased (0.036266 --> 0.035880).  Saving model ...
# Vanilla: Epoch:24 Elapsed time:00:42:00.34 	Training Loss: 0.032704 	Validation Loss: 0.034762
# Validation loss decreased (0.035880 --> 0.034762).  Saving model ...
# Vanilla: Epoch:25 Elapsed time:00:43:42.30 	Training Loss: 0.030200 	Validation Loss: 0.035588
# Vanilla: Epoch:26 Elapsed time:00:45:27.29 	Training Loss: 0.028722 	Validation Loss: 0.036241
# Vanilla: Epoch:27 Elapsed time:00:47:19.56 	Training Loss: 0.028427 	Validation Loss: 0.034521
# Validation loss decreased (0.034762 --> 0.034521).  Saving model ...
# Vanilla: Epoch:28 Elapsed time:00:49:06.20 	Training Loss: 0.027531 	Validation Loss: 0.035820
# Vanilla: Epoch:29 Elapsed time:00:50:51.68 	Training Loss: 0.025550 	Validation Loss: 0.036938
# Vanilla: Epoch:30 Elapsed time:00:52:36.99 	Training Loss: 0.026660 	Validation Loss: 0.037930
# Vanilla: Epoch:31 Elapsed time:00:54:22.63 	Training Loss: 0.025363 	Validation Loss: 0.035496
# Vanilla: Epoch:32 Elapsed time:00:56:10.10 	Training Loss: 0.023273 	Validation Loss: 0.040681
# Vanilla: Epoch:33 Elapsed time:00:57:59.01 	Training Loss: 0.022652 	Validation Loss: 0.036578
# Vanilla: Epoch:34 Elapsed time:00:59:45.61 	Training Loss: 0.022493 	Validation Loss: 0.037603
# Vanilla: Epoch:35 Elapsed time:01:01:28.50 	Training Loss: 0.021837 	Validation Loss: 0.035671
# Vanilla: Epoch:36 Elapsed time:01:03:12.36 	Training Loss: 0.020537 	Validation Loss: 0.036055
# Vanilla: Epoch:37 Elapsed time:01:04:56.47 	Training Loss: 0.020242 	Validation Loss: 0.041337
# Vanilla: Epoch:38 Elapsed time:01:06:40.79 	Training Loss: 0.020292 	Validation Loss: 0.036745
# Vanilla: Epoch:39 Elapsed time:01:08:23.44 	Training Loss: 0.019095 	Validation Loss: 0.037426
# Vanilla: Epoch:40 Elapsed time:01:10:08.38 	Training Loss: 0.019383 	Validation Loss: 0.036665

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
model.eval() # prep model for evaluation
for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.029855
#
# Test Accuracy of     0: 99% (975/980)
# Test Accuracy of     1: 99% (1130/1135)
# Test Accuracy of     2: 99% (1025/1032)
# Test Accuracy of     3: 99% (1005/1010)
# Test Accuracy of     4: 98% (971/982)
# Test Accuracy of     5: 98% (879/892)
# Test Accuracy of     6: 98% (947/958)
# Test Accuracy of     7: 98% (1017/1028)
# Test Accuracy of     8: 98% (958/974)
# Test Accuracy of     9: 98% (998/1009)
#
# Test Accuracy (Overall): 99% (9905/10000)

# %%
# obtain one batch of test images
dataiter = iter(test_loader)

# %%
images, labels = dataiter.next()
# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()
# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))

# %%
fail = False
for images, labels in dataiter:
    # get sample outputs
    output = model(images)
    # convert output probabilities to predicted class
    _, preds = torch.max(output, 1)
    # prep images for display
    images = images.numpy()
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(25, 4))
    for idx in np.arange(20):
        ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(images[idx]), cmap='gray')
        ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                    color=("green" if preds[idx]==labels[idx] else "red"))
        if preds[idx] != labels[idx]:
            fail = True
    plt.show()
    if fail:
        break

# %% [markdown]
# 모델의 학습 파라미터 수 비교

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model_v)
# Out:
# 421642

# %%
count_parameters(model)
# Out:
# 1199882

# %%
count_parameters(model_mlp)
# Out:
# 669706
